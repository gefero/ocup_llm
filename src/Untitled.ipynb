# %%
import pandas as pd

# %%
df = pd.read_csv('../data/proc/ocupaciones.csv')

# %%
def gen_prompt(string):
    spa = 'Por favor, codificá usando el Clasificador Internacional Uniforme de Ocupaciones (CIUO) del año 2008 de la Organización Internacional del Trabajo (OIT), la siguiente ocupación'
#    eng = 'Please code the following occupation using XXX of the International Labor Organization (ILO):"
    
#    if language == 'spa'
    return(spa + ': ' + "\"" + string.lower() + "\"")
   
#    if language == 'en'
#    return(en + string)

# %%
gen_prompt("PROPIETARIO DE X")
# Out:
# 'Por favor, codificá usando el Clasificador Internacional Uniforme de Ocupaciones (CIUO) del año 2008 de la Organización Internacional del Trabajo (OIT), la siguiente ocupación: "propietario de x"'

# %%
[gen_prompt(str(index['ocupacion'])) for row, index in df.reset_index().iterrows()]
# Out:
# ['Por favor, codificá usando el Clasificador Internacional Uniforme de Ocupaciones (CIUO) del año 2008 de la Organización Internacional del Trabajo (OIT), la siguiente ocupación: "empleada de atencion al publico"',
#  'Por favor, codificá usando el Clasificador Internacional Uniforme de Ocupaciones (CIUO) del año 2008 de la Organización Internacional del Trabajo (OIT), la siguiente ocupación: "portera"',
#  'Por favor, codificá usando el Clasificador Internacional Uniforme de Ocupaciones (CIUO) del año 2008 de la Organización Internacional del Trabajo (OIT), la siguiente ocupación: "tejedora"',
#  'Por favor, codificá usando el Clasificador Internacional Uniforme de Ocupaciones (CIUO) del año 2008 de la Organización Internacional del Trabajo (OIT), la siguiente ocupación: "empleado de mantenimiento"',
# ...

# %%
df['ocupacion']
# Out:
# 0        EMPLEADA DE ATENCION AL PUBLICO
# 1                                PORTERA
# 2                               TEJEDORA
# 3              EMPLEADO DE MANTENIMIENTO
# 4                         EMPLEADA RURAL
#                       ...
# 14906                          JARDINERO
# 14907                         PEON RURAL
# 14908                            ALBAÑIL
# 14909                        COMERCIANTE
# 14910                     ADMINISTRACION
# Name: ocupacion, Length: 14911, dtype: object

# %%
for row, index in df.reset_index().iterrows():
    row['o
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-a1bc6c21ded9> in <module>
#       1 for row, index in df.reset_index().iterrows():
# ----> 2     row['ocupacion']
#
# TypeError: 'int' object is not subscriptable
